# %% [markdown]
# # Task Numpy
# Following code is to load an image using cv2 library. cv2 library loads the image as numpy array. Fill missing code to replace red pixels with black codes.

# %%
import cv2
import numpy as np
from PIL import Image

im_path = "abc.png"

im_array = cv2.imread(im_path)
#im_array= np.where(im_array<255,0,im_array)
display(Image.fromarray(cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)))
# Out:
# <PIL.Image.Image image mode=RGB size=265x190 at 0x7FCF8C351880>

# %%
im_array.shape
# Out:
# (190, 265, 3)

# %%
red_mask = (im_array[:,:,0] == 0) & (im_array[:,:,1] == 0) & (im_array[:,:,2] > 20)
red_mask
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
# Set the red pixels to black
im_array[np.where(red_mask)] = [0, 0, 0]

# %%
# your code to replace
display(Image.fromarray(cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)))
# Out:
# <PIL.Image.Image image mode=RGB size=265x190 at 0x7FCF8C35DAF0>
